# %%
class  RawDataUserFilter:

    def __init__(self,textfileloc,numfile,klmfile,pathtofile):
        self.text = textfileloc
        self.num = numfile
        self.klm = klmfile
        self.path = pathtofile
    def textmaker(self):
        #opens and readies a text file containing all filenames
        filenames = open(self.text, 'r')
        filestring = filenames.read()
        listOfFilenames = filestring.split('\n')
        if self.num == 'all':
            listOfFilenames = listOfFilenames
        elif type(self.num)==int:
            listOfFilenames = listOfFilenames[0:self.num]
        elif self.num == "month1":
            listOfFilenames = getOneMonth(listOfFilenames,self.path).month1()
        else:
            print("error a non command value was inserted for numfile")
            listOfFilenames = {}
        return listOfFilenames
    
    
    def klmconverter(self):
        klmNames = (open(self.klm,'r')).read()
        klmNameList = klmNames.split('\n')
        nameList = []
        for item in klmNameList:
            nameList.append(int(float(item)))
        return nameList

    def getReplyKlmBawBB(self):
        KLMlist = RawDataUserFilter(self.text,self.num,self.klm,self.path).klmconverter()
        listOfFilenames = RawDataUserFilter(self.text,self.num,self.klm,self.path).textmaker()
        RepToBawList = []
        KLMframe = []
        for item in listOfFilenames:
            readable = jsonRead(self.path+item).JSONtoDf()
            for entry in readable.iterrows():
                try:
                    alp = int(entry[1]['in_reply_to_user_id'])
                except:
                    continue
                if alp in KLMlist:
                    KLMframe.append(entry)
        
        framelist =[]
        for item in KLMframe:
            framelist.append(item[1])
        RepToKlmList = pandas.DataFrame(framelist)
        RepToBawList.append(readable[readable['in_reply_to_user_id'] == 18332190])
        return(RepToKlmList,RepToBawList)

    def getReplyKlmBaw(self):
        #initialises the list of KLM tweets and files
        KLMlist = RawDataUserFilter(self.text,self.num,self.klm,self.path).klmconverter()
        listOfFilenames = RawDataUserFilter(self.text,self.num,self.klm,self.path).textmaker()
        #two empty lists for storage purposes
        RepToBawList = []
        KLMframe = []
        #reads through every file one at a time
        for item in listOfFilenames:
            readable = jsonRead(self.path+item).JSONtoDf()
            #Checks if the tweet is sent to one of the accounts of KLM
            for entry in readable.iterrows():
                try:
                    alp = int(entry[1]['in_reply_to_user_id'])
                except:
                    continue
                if alp in KLMlist:
                    KLMframe.append(entry)
        #creates a dataframe of tweets sent to klm
        framelist =[]
        for item in KLMframe:
            framelist.append(item[1])
        RepToKlmList = pandas.DataFrame(framelist)
        #gets a list of dataframes for tweets set to british airways
        RepToBawList.append(readable[readable['in_reply_to_user_id'] == 18332190])
        return(RepToKlmList,RepToBawList)
    
    def getKlmAll(self):
        #makes two empty list to dump all the dataframes into one for KLM one for british airways
        KLMlist = RawDataUserFilter(self.text,self.num,self.klm,self.path).klmconverter()
        listOfFilenames = RawDataUserFilter(self.text,self.num,self.klm,self.path).textmaker()
        frameklm = []
        framebrit = []
        KLMframe = []
        #creates a for-loop which sifts through all the files
        for item in listOfFilenames:
            #reminder to see where the system is currently computing
            print("handling dataset:"+item)

            #takes the filename and inserts it into the Json to Dataframe object to turn it into a dataframe
            readable = jsonRead(self.path+item).JSONtoDf()

            #initialises a counter
            usernum=0

            #checks for each user if the value is a dict, if not it gives a corresponding error message
            for i in list(readable['user']):
                if type(i)!= dict:
                    if type(i)==float:
                        print("nan value changed to empty dict")
                    elif type(i)!=float:
                        print('weird value changed to empty dict')
                    #changes non-dict values to be empty
                    readable['user'][usernum] = {}
                usernum+=1

                #takes the user dicts and turns them into rows of a dataframe
            subframe = pandas.DataFrame(list(readable['user']))
            subframe['ident'] = list(readable['id'])
            #a dataframe containing all tweets whose user id is equal to the id for a certain json
            for entry,index in zip(subframe['id'],subframe['ident']):
                try:
                    if int(entry) in KLMlist:
                        KLMframe.append(index)
                except:
                    print('fault')
                    continue
            BritWaylist = list(subframe[subframe['id']==18332190].index)

            #appends all the dataframes per json to the corresponding empty list
            frameklm.append(readable[readable['id'].isin(KLMframe)])
            framebrit.append(readable[readable.index.isin(BritWaylist)])

            #returns the lists of datasets
        return(frameklm,framebrit) 
    
    def getKlmAllBB(self):
        KLMlist = RawDataUserFilter(self.text,self.num,self.klm,self.path).klmconverter()
        listOfFilenames = RawDataUserFilter(self.text,self.num,self.klm,self.path).textmaker()
        frameklm = []
        framebrit = []
        KLMframe = []
        for item in listOfFilenames:
            readable = jsonRead(self.path+item).JSONtoDf()
            usernum=0
            for i in list(readable['user']):
                if type(i)!= dict:
                    readable['user'][usernum] = {}
                usernum+=1
            subframe = pandas.DataFrame(list(readable['user']))
            subframe['ident'] = list(readable['id'])
            for entry,index in zip(subframe['id'],subframe['ident']):
                try:
                    if int(entry) in KLMlist:
                        KLMframe.append(index)     
                except:
                    continue
            BritWaylist = list(subframe[subframe['id']==18332190].index)
            frameklm.append(readable[readable['id'].isin(KLMframe)])
            framebrit.append(readable[readable.index.isin(BritWaylist)])
        return(frameklm,framebrit)

# %%
class FrameConcat:
    
    def __init__(self,doubleframe):
        self.frames = doubleframe
    
    def concatinator(self):
        concatframes = []
        for i in range(2):
            Rep= self.frames[i]
            try:
                concatframes.append(pandas.concat(Rep,ignore_index=True))
            except:
                concatframes.append(Rep)
        return concatframes

# %%
class getOneMonth:
    
    def __init__(self,file,path):
        self.file = file
        self.path = path
   
    def month1(self):
        Filelist = []
        for item in self.file:
            if 'lastofjune.json' not in Filelist:
                Filelist.append(getOneMonth(item,self.path).jsonwrites())
            else:
                return Filelist
            
    def jsonwrites(self):
        data = []
        with open(self.path+self.file) as f:
            for line in f:
                jsonline =json.loads(line)
                date = jsonline['created_at']
                if date[6] == 'l' and date[9]=='1':
                    output_file = open(self.path+'lastofjune.json','w')
                    for jsonline in data:
                        json.dump(jsonline,output_file)
                        output_file.write("\n")
                    return 'lastofjune.json'
                elif date[6]=='n' and date[8]=='3':
                    data.append(jsonline)
                else:
                    return self.file
            return self.file

# %%
#necessairy libraries
import pandas
import json

#class object
class jsonRead:
        #sets the file location as the self.name
    def __init__(self , filename):
        self.name = filename
        
        #function which reads the json lines and puts them into a dataframe
    def JSONtoDf(self):
        #list to dump json files into
        data = []
        #initialises linecounter for later usage
        linecount = 0
        # takes the self.name opens it and assigns it to the variable f
        with open(self.name) as f:
            #line is one line of json
            for line in f:
                linecount +=1
                #tries to append the json line to the list, if it fails it prints the json that caused the exception
                try:
                    data.append(json.loads(line))
                except:
                    print("fault in line:"+str(linecount))
        #turns the list into a dataframe and returns it
        son = pandas.DataFrame(data)
        return son

# %%
sentbyList = RawDataUserFilter('json/filenames.txt','month1','KLMnumb shortlist.txt', 'json/').getKlmAllBB()
# Out:
# fault in line:3318
# fault in line:4785
# fault in line:304
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# fault in line:5331
# fault in line:2935
# fault in line:6451

# %%
sentbyList = FrameConcat(sentbyList).concatinator()

# %%
TlistKlm = sentbyList[0]
TlistBaw = sentbyList[1]

# %%
repListKlm = []
for item in TlistKlm.iterrows():
    if "@" in item[1]['text']:
        repListKlm.append(item[1])
repKlm = pandas.DataFrame(repListKlm)

# %%
value = 0
current_date = 'null'
userRepliedTo = []

for tweet in repKlm.iterrows():
    if tweet[1]['created_at'][0:10] != current_date:
        current_date = tweet[1]['created_at'][0:10]
        value +=1
    tweet[1]['date'] = value
    userRepliedTo.append(tweet[1])

userRepliedTo = pandas.DataFrame(userRepliedTo)
userRepliedTo['rep_name']= userRepliedTo['text'].str.extract(r'.*(@[a-zA-Z0-9_]*).*')
userRepliedTo = userRepliedTo[userRepliedTo['rep_name']!='@']
userRepliedTo = userRepliedTo[userRepliedTo['rep_name'].str.extract(r'@(KLM).*')!='KLM']
userRepliedTo = userRepliedTo[userRepliedTo['rep_name'] !='@klm']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   from ipykernel import kernelapp as app

# %%
userlist = list(userRepliedTo['rep_name'])
userlist = list(dict.fromkeys(userlist))
userdict ={}
for user in userlist:
    userdict[user] = []

for tweet in userRepliedTo.iterrows():
    try:
        userdict[tweet[1]['rep_name']].append(tweet[1])
    except:
        print('non dict value appended')

dfpersons = []
for person in userdict.keys():
    dfpersons.append(userdict[person])

dfpersons
# Out:
# [[contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 10:04:26 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37223e+17
#   id_str                                                      737223132034039808
#   in_reply_to_screen_name                                              atckuoh91
#   in_reply_to_status_id                                              7.37195e+17
#   in_reply_to_status_id_str                                   737194519662231552
#   in_reply_to_user_id                                                2.88253e+09
#   in_reply_to_user_id_str                                             2882527336
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @atckuoh91 Indeed Alan, you are entitled to 2 ...
#   timestamp_ms                                                     1464602666277
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                            @atckuoh91
#   Name: 0, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 11:01:59 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37238e+17
#   id_str                                                      737237616475701249
#   in_reply_to_screen_name                                         nicoleharding1
#   in_reply_to_status_id                                              7.37222e+17
#   in_reply_to_status_id_str                                   737221966730539008
#   in_reply_to_user_id                                                9.50599e+07
#   in_reply_to_user_id_str                                               95059891
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @nicoleharding1 Thank you for you kind words, ...
#   timestamp_ms                                                     1464606119637
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                       @nicoleharding1
#   Name: 4, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 11:05:39 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37239e+17
#   id_str                                                      737238537821519872
#   in_reply_to_screen_name                                                  PZa81
#   in_reply_to_status_id                                              7.37229e+17
#   in_reply_to_status_id_str                                   737229374131408896
#   in_reply_to_user_id                                                2.53619e+07
#   in_reply_to_user_id_str                                               25361927
#   is_quote_status                                                          False
#   lang                                                                        nl
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @PZa81 Hallo Patrick, op intercontinentale KLM...
#   timestamp_ms                                                     1464606339303
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                                @PZa81
#   Name: 5, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 11:21:31 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37243e+17
#   id_str                                                      737242530253791233
#   in_reply_to_screen_name                                          semajsenrab72
#   in_reply_to_status_id                                              7.37224e+17
#   in_reply_to_status_id_str                                   737224281856167936
#   in_reply_to_user_id                                                3.37121e+09
#   in_reply_to_user_id_str                                             3371210360
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @semajsenrab72 Since January 2016, KLM has bee...
#   timestamp_ms                                                     1464607291173
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                        @semajsenrab72
#   Name: 6, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 11:38:57 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37247e+17
#   id_str                                                      737246916979888128
#   in_reply_to_screen_name                                             HelloDalek
#   in_reply_to_status_id                                              7.37228e+17
#   in_reply_to_status_id_str                                   737228239169544192
#   in_reply_to_user_id                                                3.17944e+09
#   in_reply_to_user_id_str                                             3179444548
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @HelloDalek Of late, KLM has been gradually ph...
#   timestamp_ms                                                     1464608337050
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                           @HelloDalek
#   Name: 7, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 11:44:41 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37248e+17
#   id_str                                                      737248362127360000
#   in_reply_to_screen_name                                            stuart_gray
#   in_reply_to_status_id                                               7.3723e+17
#   in_reply_to_status_id_str                                   737230173112799233
#   in_reply_to_user_id                                                1.49974e+08
#   in_reply_to_user_id_str                                              149974000
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @stuart_gray KLM to the rescue! ;) Please shar...
#   timestamp_ms                                                     1464608681600
#   truncated                                                                False
#   user                         {'id': 19401532, 'id_str': '19401532', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                          @stuart_gray
#   Name: 8, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 12:17:24 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37257e+17
#   id_str                                                      737256593717223424
#   in_reply_to_screen_name                                            RenesPoints
#   in_reply_to_status_id                                              7.37236e+17
#   in_reply_to_status_id_str                                   737235740531138560
#   in_reply_to_user_id                                                 3.2909e+08
#   in_reply_to_user_id_str                                              329090201
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @RenesPoints We are sad to say goodbye too. Si...
#   timestamp_ms                                                     1464610644164
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                          @RenesPoints
#   Name: 9, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 13:03:40 +0000 2016
#   entities                     {'hashtags': [], 'urls': [{'url': 'https://t.c...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37268e+17
#   id_str                                                      737268236639604736
#   in_reply_to_screen_name                                              ATNY_Boss
#   in_reply_to_status_id                                              7.37245e+17
#   in_reply_to_status_id_str                                   737244865671626752
#   in_reply_to_user_id                                                2.63317e+08
#   in_reply_to_user_id_str                                              263316942
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                       False
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @ATNY_Boss Hi, Godsped. Why don't you check ou...
#   timestamp_ms                                                     1464613420053
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                            @ATNY_Boss
#   Name: 10, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 13:51:47 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                  7.3728e+17
#   id_str                                                      737280349160542208
#   in_reply_to_screen_name                                             Lale_rossi
#   in_reply_to_status_id                                              7.37255e+17
#   in_reply_to_status_id_str                                   737255344150319104
#   in_reply_to_user_id                                                2.73537e+08
#   in_reply_to_user_id_str                                              273536637
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @Lale_rossi &lt; from London Gatwick to Amster...
#   timestamp_ms                                                     1464616307903
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                           @Lale_rossi
#   Name: 11, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 14:04:57 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37284e+17
#   id_str                                                      737283660483858434
#   in_reply_to_screen_name                                               loreadne
#   in_reply_to_status_id                                                      NaN
#   in_reply_to_status_id_str                                                 None
#   in_reply_to_user_id                                                2.84037e+08
#   in_reply_to_user_id_str                                              284036521
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @loreadne &gt;&gt; check if there is any alter...
#   timestamp_ms                                                     1464617097384
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                             @loreadne
#   Name: 12, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Mon May 30 14:09:10 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37285e+17
#   id_str                                                      737284721936338944
#   in_reply_to_screen_name                                           amerogabriel
#   in_reply_to_status_id                                               7.3726e+17
#   in_reply_to_status_id_str                                   737260189670211584
#   in_reply_to_user_id                                                3.16162e+09
#   in_reply_to_user_id_str                                             3161622738
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @amerogabriel KLM actively invests in fleet re...
#   timestamp_ms                                                     1464617350454
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         1
#   rep_name                                                         @amerogabriel
#   Name: 13, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Tue May 31 08:28:49 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37561e+17
#   id_str                                                      737561457705918465
#   in_reply_to_screen_name                                             BIKEZONENL
#   in_reply_to_status_id                                              7.37556e+17
#   in_reply_to_status_id_str                                   737555849573371910
#   in_reply_to_user_id                                                  9.107e+07
#   in_reply_to_user_id_str                                               91069982
#   is_quote_status                                                          False
#   lang                                                                        nl
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @BIKEZONENL Dat is vervelend, excuses voor het...
#   timestamp_ms                                                     1464683329403
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         2
#   rep_name                                                           @BIKEZONENL
#   Name: 14, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Tue May 31 10:46:36 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37596e+17
#   id_str                                                      737596134026153984
#   in_reply_to_screen_name                                           dwfotografie
#   in_reply_to_status_id                                              7.37584e+17
#   in_reply_to_status_id_str                                   737584219547832324
#   in_reply_to_user_id                                                7.04744e+07
#   in_reply_to_user_id_str                                               70474418
#   is_quote_status                                                          False
#   lang                                                                        nl
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @dwfotografie Dag Douwe, wat leuk dat je inter...
#   timestamp_ms                                                     1464691596882
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         2
#   rep_name                                                         @dwfotografie
#   Name: 17, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Wed Jun 01 10:16:54 +0000 2016
#   entities                     {'hashtags': [{'text': 'KLMOpen', 'indices': [...
#   extended_entities            {'media': [{'id': 737951043741450241, 'id_str'...
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37951e+17
#   id_str                                                      737951046996262912
#   in_reply_to_screen_name                                                   None
#   in_reply_to_status_id                                                      NaN
#   in_reply_to_status_id_str                                                 None
#   in_reply_to_user_id                                                        NaN
#   in_reply_to_user_id_str                                                   None
#   is_quote_status                                                          False
#   lang                                                                        nl
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                       False
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://twitter.com" rel="nofollow">Tw...
#   text                         KLM Open met Beat The Pro uniek op @EuropeanTo...
#   timestamp_ms                                                     1464776214728
#   truncated                                                                False
#   user                         {'id': 50648342, 'id_str': '50648342', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         3
#   rep_name                                                         @EuropeanTour
#   Name: 21, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Wed Jun 01 11:21:17 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37967e+17
#   id_str                                                      737967248183308288
#   in_reply_to_screen_name                                            vantrooijen
#   in_reply_to_status_id                                              7.37957e+17
#   in_reply_to_status_id_str                                   737956705711988736
#   in_reply_to_user_id                                                1.42023e+08
#   in_reply_to_user_id_str                                              142023225
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @vantrooijen KLM actively invests in fleet ren...
#   timestamp_ms                                                     1464780077392
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         3
#   rep_name                                                          @vantrooijen
#   Name: 22, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Wed Jun 01 12:37:01 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37986e+17
#   id_str                                                      737986305481682944
#   in_reply_to_screen_name                                             SpieleWERT
#   in_reply_to_status_id                                              7.37979e+17
#   in_reply_to_status_id_str                                   737979183599652864
#   in_reply_to_user_id                                                 3.2404e+09
#   in_reply_to_user_id_str                                             3240396143
#   is_quote_status                                                          False
#   lang                                                                        de
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @SpieleWERT Wir haben doch mehr als nur ein Fl...
#   timestamp_ms                                                     1464784621006
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                         3
#   rep_name                                                           @SpieleWERT
#   Name: 23, dtype: object,
#   contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Wed Jun 01 13:19:04 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.37997e+17
#   id_str                                                      737996890311163905
# ...
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @Kerst_L &gt;&gt;&gt; passagiers, veranderen A...
#   timestamp_ms                                                     1467266165392
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                              @Kerst_L
#   Name: 427, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Thu Jun 30 10:22:56 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.48462e+17
#   id_str                                                      748461810580348928
#   in_reply_to_screen_name                                             FCozzolino
#   in_reply_to_status_id                                              7.48444e+17
#   in_reply_to_status_id_str                                   748444150173962240
#   in_reply_to_user_id                                                3.82398e+09
#   in_reply_to_user_id_str                                             3823982963
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @FCozzolino With reference to your query, we w...
#   timestamp_ms                                                     1467282176047
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                           @FCozzolino
#   Name: 430, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Thu Jun 30 13:29:06 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.48509e+17
#   id_str                                                      748508661350273024
#   in_reply_to_screen_name                                          pitcherkiller
#   in_reply_to_status_id                                              7.48506e+17
#   in_reply_to_status_id_str                                   748506039834710016
#   in_reply_to_user_id                                                1.54762e+08
#   in_reply_to_user_id_str                                              154761604
#   is_quote_status                                                          False
#   lang                                                                        ko
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                                   @pitcherkiller 저희 KLM 에 주신 관심 감사합니다. :)
#   timestamp_ms                                                     1467293346141
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                        @pitcherkiller
#   Name: 433, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Thu Jun 30 14:38:26 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.48526e+17
#   id_str                                                      748526112767094784
#   in_reply_to_screen_name                                             jonathanjo
#   in_reply_to_status_id                                              7.48515e+17
#   in_reply_to_status_id_str                                   748514718113992704
#   in_reply_to_user_id                                                1.27974e+06
#   in_reply_to_user_id_str                                                1279741
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @jonathanjo &lt;Could you please also inform u...
#   timestamp_ms                                                     1467297506883
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                           @jonathanjo
#   Name: 434, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Thu Jun 30 20:05:00 +0000 2016
#   entities                     {'hashtags': [], 'urls': [], 'user_mentions': ...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.48608e+17
#   id_str                                                      748608293984153604
#   in_reply_to_screen_name                                                mac3552
#   in_reply_to_status_id                                              7.48574e+17
#   in_reply_to_status_id_str                                   748574020170301448
#   in_reply_to_user_id                                                2.17353e+08
#   in_reply_to_user_id_str                                              217352791
#   is_quote_status                                                          False
#   lang                                                                        en
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                         NaN
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @mac3552 If you don't have a check in baggage,...
#   timestamp_ms                                                     1467317100412
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                              @mac3552
#   Name: 437, dtype: object],
#  [contributors                                                               NaN
#   coordinates                                                               None
#   created_at                                      Thu Jun 30 20:34:01 +0000 2016
#   entities                     {'hashtags': [], 'urls': [{'url': 'https://t.c...
#   extended_entities                                                          NaN
#   favorite_count                                                               0
#   favorited                                                                False
#   filter_level                                                               low
#   geo                                                                       None
#   id                                                                 7.48616e+17
#   id_str                                                      748615596246441984
#   in_reply_to_screen_name                                               mvsocial
#   in_reply_to_status_id                                              7.48614e+17
#   in_reply_to_status_id_str                                   748613981389131776
#   in_reply_to_user_id                                                6.78942e+07
#   in_reply_to_user_id_str                                               67894244
#   is_quote_status                                                          False
#   lang                                                                        nl
#   limit                                                                      NaN
#   place                                                                     None
#   possibly_sensitive                                                       False
#   quoted_status                                                              NaN
#   quoted_status_id                                                           NaN
#   quoted_status_id_str                                                       NaN
#   retweet_count                                                                0
#   retweeted                                                                False
#   retweeted_status                                                           NaN
#   scopes                                                                     NaN
#   source                       <a href="http://www.radian6.com" rel="nofollow...
#   text                         @mvsocial Hallo, dat vinden we vervelend om te...
#   timestamp_ms                                                     1467318841407
#   truncated                                                                False
#   user                         {'id': 56377143, 'id_str': '56377143', 'name':...
#   withheld_in_countries                                                      NaN
#   date                                                                        24
#   rep_name                                                             @mvsocial
#   Name: 438, dtype: object]]

# %%
# Out:
# ['@atckuoh91',
#  '@nicoleharding1',
#  '@PZa81',
#  '@semajsenrab72',
#  '@HelloDalek',
#  '@stuart_gray',
#  '@RenesPoints',
#  '@ATNY_Boss',
#  '@Lale_rossi',
#  '@loreadne',
#  '@amerogabriel',
#  '@BIKEZONENL',
#  '@dwfotografie',
#  '@EuropeanTour',
#  '@vantrooijen',
#  '@SpieleWERT',
#  '@itisromane',
#  '@jaspergeelen',
#  '@RodaJCHeadlines',
#  '@davidrueda30',
#  '@sirlordio',
#  '@DAllan1970',
#  '@postvak',
#  '@konnyface',
#  '@ErinThePerin',
#  '@HAEVNMUSIC',
#  '@TLKooi',
#  '@ruby_sande',
#  '@Tuan_Le_',
#  '@DavidJFinlay',
#  '@uwsdub',
#  '@dhont64',
#  '@jcouckuy',
#  '@AngelesCarnelli',
#  '@romantikker',
#  '@AhmadSaadOv',
#  '@vdpoorten',
#  '@EllenPetit',
#  '@jamesnewton007',
#  '@FreekToTake',
#  '@dirkjanu',
#  '@johnbentleyace',
#  '@keesjanssen95',
#  '@jamiekun_jp',
#  '@erwin271084',
#  '@FokkoTweets',
#  '@careon95',
#  '@aehegewisch',
#  '@__Kimoo',
#  '@BoBoBaBagins',
#  '@Chris_Ntaskas',
#  '@xentoni',
#  '@thali_i',
#  '@van_Rukhoven',
#  '@yaeloc',
#  '@FRAAviation',
#  '@HazeWilkinson',
#  '@Geadaaa',
#  '@Partingoli',
#  '@NurbolSeitekhan',
#  '@sophiessuitcse',
#  '@timsekac',
#  '@AnastasiaSivach',
#  '@RobdeVroet',
#  '@iLove_Aviation',
#  '@quviq',
#  '@GideonMokho',
#  '@newhang',
#  '@tom_mclaren74',
#  '@GuiF007',
#  '@CTurnock',
#  '@MaksOosterbaan',
#  '@nuclearsunshine',
#  '@FlyTeamNews',
#  '@peetersjeroen',
#  '@case800',
#  '@pabletepucela',
#  '@nottakenyet',
#  '@asxtcc',
#  '@yudaffi',
#  '@Bozmorris',
#  '@AHurtado90',
#  '@PortiaOti',
#  '@KennethAttv',
#  '@petrussola',
#  '@VizziniAntonio',
#  '@ManasiScott',
#  '@name4your6',
#  '@boeing787tweets',
#  '@Stukje89',
#  '@vannorel85',
#  '@bas_sebas',
#  '@girls_20thC',
#  '@TPrevoo',
#  '@swtimmer',
#  '@IngmarVerheij',
#  '@sashimi12',
#  '@AvGeekAlex',
#  '@Valia_geo',
#  '@pukkepukstra',
#  '@aaronkatemba',
#  '@SSRPillai',
#  '@julesdw',
#  '@houtenvanmark',
#  '@kleeberg_lopez',
#  '@MyKneeKing',
#  '@vrkcosta',
#  '@brossinaktie',
#  '@Menno020',
#  '@remhelms',
#  '@epturismo',
#  '@Niels_Speijer',
#  '@MaartenterHoeve',
#  '@SossieNL',
#  '@AnitaYiyavm',
#  '@der_Basskrieger',
#  '@christravelblog',
#  '@Dominik_R',
#  '@nvv0505',
#  '@LadyyC',
#  '@JoopHupkes',
#  '@edwinoost',
#  '@Nico1994Nicomax',
#  '@XBikbergen',
#  '@bergthil',
#  '@HernanLaCruz',
#  '@natashajdouglas',
#  '@Asamoh_',
#  '@lonestarswift13',
#  '@ruzinRS',
#  '@HittaNymo',
#  '@corineholtmaat',
#  '@Rodgrode',
#  '@_bjct',
#  '@ObembeTemitope',
#  '@LaBlueBlues',
#  '@mutsumi0302',
#  '@andomifuyu',
#  '@skyteam',
#  '@rietcheese',
#  '@ZoeAndrewsNcl',
#  '@cobenvent',
#  '@vertanthony56',
#  '@nlTom',
#  '@ExtraTrainer',
#  '@LilyGreenRoom',
#  '@lady_di_30',
#  '@Mnca',
#  '@S_kotnala',
#  '@DublinAirport',
#  '@Ahall41116',
#  '@NJABEN',
#  '@Papillon60',
#  '@BenDudleyx',
#  '@pitcordova',
#  '@rankiryuko',
#  '@MarllonEmerson',
#  '@_amitpandey',
#  '@ireland',
#  '@DiscoverIreland',
#  '@dtyczynski',
#  '@EHMinnema',
#  '@Captain_Law',
#  '@BenjaminVBr',
#  '@CCartwright1984',
#  '@fritsterkuile',
#  '@leefowkes',
#  '@lovelyjen69',
#  '@RajaRazwanAslam',
#  '@kbystrov_ep',
#  '@mchlrv',
#  '@ManonOui',
#  '@emmafacturanan',
#  '@bgoncalves',
#  '@mads_jacobsen',
#  '@MeenieH210',
#  '@vrijilesh',
#  '@NicolasCediey',
#  '@stevenhallnufc',
#  '@Lordshazellton',
#  '@rahul_suv',
#  '@gjkooijman',
#  '@aichouka',
#  '@FrankieOdie',
#  '@Neda_Kesh',
#  '@jerry_downing69',
#  '@michael_diers',
#  '@MrGayEspana',
#  '@willemjz',
#  '@indeverkarsija',
#  '@mvanhall',
#  '@PimSonnenberg',
#  '@alidestorm',
#  '@RKAlimitless',
#  '@monicadramisino',
#  '@Marseaplage',
#  '@ghanege',
#  '@thomasvdmeer24',
#  '@Marloes_Haarsma',
#  '@laypark1',
#  '@joop',
#  '@SignifiKirsten',
#  '@fooohke',
#  '@SanderTroost',
#  '@bullmuck27',
#  '@FemDolly',
#  '@ptooher',
#  '@Kerst_L',
#  '@FCozzolino',
#  '@pitcherkiller',
#  '@jonathanjo',
#  '@mac3552',
#  '@mvsocial']

# %%
replist = []
for person in dfpersons:
    for tweet in person.iterrows():
        bar = tweet[1]['in_reply_to_status_id_str']
        if bar != None:
            replist.append(bar)
replist
# Out:
# ['737194519662231552',
#  '737221966730539008',
#  '737229374131408896',
#  '737224281856167936',
#  '737228239169544192',
#  '737230173112799233',
#  '737235740531138560',
#  '737244865671626752',
#  '737255344150319104',
#  '737260189670211584',
#  '737555849573371910',
#  '737584219547832324',
#  '737956705711988736',
#  '737979183599652864',
#  '737994003602378752',
#  '738027663185608704',
#  '738030176567742465',
#  '738043422532075520',
#  '738032875858210816',
#  '738116102077730817',
#  '738063756266201088',
#  '738077574191022080',
#  '738286568352452608',
#  '738323426478333952',
#  '738330617486675968',
#  '738332475278143488',
#  '738320170603667456',
#  '738321568401620992',
#  '738321568401620992',
#  '738332936152469505',
#  '738343607728476160',
#  '738321515154919425',
#  '738417579937681410',
#  '738410721780858880',
#  '738621864168194048',
#  '738645200537554944',
#  '738663529092423680',
#  '738667978150006785',
#  '738642741735919616',
#  '738682791282511873',
#  '738706058873589760',
#  '738710092304896000',
#  '738715902808592385',
#  '738771080974872576',
#  '738781673685274625',
#  '738746637657485312',
#  '738824472615079936',
#  '738871484303675393',
#  '739001960066633728',
#  '739066001803890688',
#  '739098041551048705',
#  '739150600923930625',
#  '739165159046926336',
#  '739183871913254912',
#  '739203271882084352',
#  '739239501571235842',
#  '739369064422907904',
#  '739483512936357888',
#  '739563193329160192',
#  '739564274859802632',
#  '739557390874447876',
#  '739742726023983104',
#  '739812182683062272',
#  '739902576678850560',
#  '739851246799093760',
#  '739938633600339970',
#  '740107435340386304',
#  '740125551835422724',
#  '740163733452955648',
#  '740155400138285056',
#  '740156683205398529',
#  '740147062352707585',
#  '740147062352707585',
#  '740063148020006912',
#  '740213753405444096',
#  '740232789795217408',
#  '740078903910338560',
#  '740193272702898176',
#  '740105261382242304',
#  '740214077679620096',
#  '740214077679620096',
#  '740208980081807362',
#  '740309458329448448',
#  '740309458329448448',
#  '740358725249048576',
#  '740457822492758017',
#  '740485057421430784',
#  '740480365253517316',
#  '740526770470977536',
#  '740526770470977536',
#  '740567514225082369',
#  '740575051179823105',
#  '740593251875454976',
#  '740567730525442049',
#  '740818425631637504',
#  '740847790222389248',
#  '740837566711275520',
#  '740854922544074753',
#  '740845876072095744',
#  '740866260657831936',
#  '740868800313217025',
#  '740872279702265857',
#  '740880437690695680',
#  '740870321079767040',
#  '740975568888471552',
#  '740932525586063361',
#  '741029014639251456',
#  '741169209707778048',
#  '741176593775726592',
#  '741193239525527552',
#  '741193239525527552',
#  '741259318713024516',
#  '741282797537660928',
#  '741258423623389184',
#  '741281279195422720',
#  '741330836142850048',
#  '741330836142850048',
#  '741296070412644352',
#  '741373641598865408',
#  '741352937780285440',
#  '741517149873790976',
#  '741517149873790976',
#  '741590654892048384',
#  '741590654892048384',
#  '741609122366382080',
#  '741609122366382080',
#  '741600974666670081',
#  '741638938163564544',
#  '741654284723441664',
#  '741673845027930112',
#  '741700380019597312',
#  '741721653705478144',
#  '741721653705478144',
#  '741825761242456064',
#  '741919499910316036',
#  '741942757950935040',
#  '741984643789029376',
#  '742019820728639488',
#  '742041459877154816',
#  '742041459877154816',
#  '742016289074348032',
#  '744800762585198592',
#  '744832503161065476',
#  '744912600593403904',
#  '744904148664131584',
#  '744935233116569601',
#  '745037953387405312',
#  '745047082877198336',
#  '745047233805041665',
#  '744998831415304193',
#  '745181716189351936',
#  '745190534864637952',
#  '745177790861840384',
#  '744941867817639936',
#  '745221265280106496',
#  '745223269901570053',
#  '745213567876501504',
#  '745279932306178052',
#  '745291405132767232',
#  '745346046021242881',
#  '745314647083982849',
#  '745314647083982849',
#  '745314647083982849',
#  '745345686670024704',
#  '745407440510984193',
#  '745498677930713088',
#  '745594945864667137',
#  '745594945864667137',
#  '745608345353093120',
#  '745602603736784897',
#  '745599878818988032',
#  '746708558599823361',
#  '745679584956420096',
#  '745664902359035904',
#  '745644866240155648',
#  '745704633297965056',
#  '745690534279286784',
#  '745942801628692480',
#  '745994594328920064',
#  '746093814813761540',
#  '746048674191544320',
#  '746305500854239232',
#  '746065179083948032',
#  '746192463417614336',
#  '746226280043929601',
#  '746254146030936064',
#  '746414827409649664',
#  '746638290015617024',
#  '746716701568438272',
#  '746741219712188416',
#  '746819663854698497',
#  '746819663854698497',
#  '747391263066963968',
#  '747430163550461952',
#  '747415842791489536',
#  '747458924740218881',
#  '747480693932843012',
#  '747669949347409920',
#  '747694193380823040',
#  '747810742519365632',
#  '747813575465406464',
#  '747873804517511169',
#  '747876480466694144',
#  '747876480466694144',
#  '747876480466694144',
#  '747893238007201792',
#  '747930171366322178',
#  '748043707925037056',
#  '748103262570582017',
#  '748036141992022016',
#  '748058025995476992',
#  '748105234501742592',
#  '748118327940218880',
#  '748129516053209088',
#  '748128139247755266',
#  '748151928996106242',
#  '748157717882245120',
#  '748391454045777920',
#  '748444150173962240',
#  '748506039834710016',
#  '748514718113992704',
#  '748574020170301448',
#  '748613981389131776']

# %%
textlist = RawDataUserFilter('json/filenames.txt','month1',3,'json/').textmaker()
data = []
for filename in textlist:
        linecount = 0
        with open('json/'+filename) as f:
            for line in f:
                linecount +=1
                try:
                    curline = json.loads(line)
                    if curline['id_str'] in replist:
                        data.append(curline)
                except:
                    print("fault in line:"+str(linecount))
pandas.DataFrame(data)
# Out:
# fault in line:3318
# fault in line:2582
# fault in line:2600
# fault in line:4785
# fault in line:304
# fault in line:5331
# fault in line:2935
# fault in line:13549
# fault in line:13605
# fault in line:13855
# fault in line:13939
# fault in line:13949
# fault in line:7437
# fault in line:7458
# fault in line:7460
# fault in line:2485
# fault in line:2489
# fault in line:1910
# fault in line:1915
# fault in line:1920
# fault in line:4712
# fault in line:4715
# fault in line:4719
# fault in line:11993
# fault in line:227
# fault in line:3760
# fault in line:13858
# fault in line:13867
# fault in line:13897
# fault in line:10404
# fault in line:10408
# fault in line:10412
# fault in line:10445
# fault in line:10895
# fault in line:10957
# fault in line:11023
# fault in line:12047
# fault in line:12049
# fault in line:12053
# fault in line:12069
# fault in line:12087
# fault in line:6451
#     contributors coordinates                      created_at  \
# 0           None        None  Mon May 30 09:59:48 +0000 2016
# 1           None        None  Mon May 30 10:09:00 +0000 2016
# 2           None        None  Mon May 30 10:24:43 +0000 2016
# 3           None        None  Mon May 30 10:29:14 +0000 2016
# 4           None        None  Mon May 30 10:54:32 +0000 2016
# 5           None        None  Mon May 30 11:30:47 +0000 2016
# 6           None        None  Mon May 30 12:12:26 +0000 2016
# 7           None        None  Mon May 30 12:31:41 +0000 2016
# 8           None        None  Tue May 31 08:06:32 +0000 2016
# 9           None        None  Tue May 31 09:59:16 +0000 2016
# 10          None        None  Wed Jun 01 10:39:23 +0000 2016
# 11          None        None  Wed Jun 01 12:08:43 +0000 2016
# 12          None        None  Wed Jun 01 13:07:36 +0000 2016
# 13          None        None  Wed Jun 01 15:21:21 +0000 2016
# 14          None        None  Wed Jun 01 15:31:20 +0000 2016
# 15          None        None  Wed Jun 01 15:42:04 +0000 2016
# 16          None        None  Wed Jun 01 16:23:58 +0000 2016
# 17          None        None  Wed Jun 01 17:44:46 +0000 2016
# 18          None        None  Wed Jun 01 18:39:41 +0000 2016
# 19          None        None  Wed Jun 01 21:12:46 +0000 2016
# 20          None        None  Thu Jun 02 08:30:09 +0000 2016
# 21          None        None  Thu Jun 02 10:43:40 +0000 2016
# 22          None        None  Thu Jun 02 10:49:13 +0000 2016
# 23          None        None  Thu Jun 02 10:56:36 +0000 2016
# 24          None        None  Thu Jun 02 11:25:11 +0000 2016
# 25          None        None  Thu Jun 02 11:32:34 +0000 2016
# 26          None        None  Thu Jun 02 11:34:24 +0000 2016
# 27          None        None  Thu Jun 02 12:16:48 +0000 2016
# 28          None        None  Thu Jun 02 16:43:29 +0000 2016
# 29          None        None  Thu Jun 02 17:10:44 +0000 2016
# ..           ...         ...                             ...
# 148         None        None  Sat Jun 25 09:36:54 +0000 2016
# 149         None        None  Sat Jun 25 14:48:29 +0000 2016
# 150         None        None  Sat Jun 25 16:25:55 +0000 2016
# 151         None        None  Mon Jun 27 11:28:57 +0000 2016
# 152         None        None  Mon Jun 27 13:06:37 +0000 2016
# 153         None        None  Mon Jun 27 14:03:32 +0000 2016
# 154         None        None  Mon Jun 27 15:57:49 +0000 2016
# 155         None        None  Mon Jun 27 17:24:19 +0000 2016
# 156         None        None  Tue Jun 28 05:56:21 +0000 2016
# 157         None        None  Tue Jun 28 07:32:41 +0000 2016
# 158         None        None  Tue Jun 28 15:15:49 +0000 2016
# 159         None        None  Tue Jun 28 15:27:04 +0000 2016
# 160         None        None  Tue Jun 28 19:26:24 +0000 2016
# 161         None        None  Tue Jun 28 20:43:37 +0000 2016
# 162         None        None  Tue Jun 28 23:10:23 +0000 2016
# 163         None        None  Wed Jun 29 06:11:28 +0000 2016
# 164         None        None  Wed Jun 29 06:41:32 +0000 2016
# 165         None        None  Wed Jun 29 07:38:26 +0000 2016
# 166         None        None  Wed Jun 29 10:38:11 +0000 2016
# 167         None        None  Wed Jun 29 10:46:01 +0000 2016
# 168         None        None  Wed Jun 29 11:38:03 +0000 2016
# 169         None        None  Wed Jun 29 12:22:30 +0000 2016
# 170         None        None  Wed Jun 29 13:51:34 +0000 2016
# 171         None        None  Wed Jun 29 14:14:34 +0000 2016
# 172         None        None  Thu Jun 30 05:43:21 +0000 2016
# 173         None        None  Thu Jun 30 09:12:45 +0000 2016
# 174         None        None  Thu Jun 30 13:18:41 +0000 2016
# 175         None        None  Thu Jun 30 13:53:10 +0000 2016
# 176         None        None  Thu Jun 30 17:48:48 +0000 2016
# 177         None        None  Thu Jun 30 20:27:36 +0000 2016
#
#                                               entities  \
# 0    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3    {'hashtags': [{'text': 'usa', 'indices': [61, ...
# 4    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 6    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 8    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 9    {'hashtags': [{'text': 'stouteschoenen', 'indi...
# 10   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 11   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 12   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 13   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 14   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 15   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 16   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 17   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 18   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 19   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 20   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 21   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 22   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 23   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 24   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 25   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 26   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 27   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 28   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 29   {'hashtags': [], 'urls': [], 'user_mentions': ...
# ..                                                 ...
# 148  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 149  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 150  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 151  {'hashtags': [{'text': 'oranje', 'indices': [9...
# 152  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 153  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 154  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 155  {'hashtags': [{'text': 'UltraEurope', 'indices...
# 156  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 157  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 158  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 159  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 160  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 161  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 162  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 163  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 164  {'hashtags': [{'text': 'KLM암스테르담전망대', 'indices...
# 165  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 166  {'hashtags': [{'text': 'KLM암스테르담전망대', 'indices...
# 167  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 168  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 169  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 170  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 171  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 172  {'hashtags': [{'text': 'samenopreis', 'indices...
# 173  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 174  {'hashtags': [{'text': 'KLM암스테르담전망대', 'indices...
# 175  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 176  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 177  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                      extended_entities  favorite_count  \
# 0                                                  NaN               0
# 1                                                  NaN               0
# 2                                                  NaN               0
# 3                                                  NaN               0
# 4                                                  NaN               0
# 5                                                  NaN               0
# 6                                                  NaN               0
# 7                                                  NaN               0
# 8                                                  NaN               0
# 9                                                  NaN               0
# 10                                                 NaN               0
# 11                                                 NaN               0
# 12                                                 NaN               0
# 13                                                 NaN               0
# 14                                                 NaN               0
# 15                                                 NaN               0
# 16                                                 NaN               0
# 17                                                 NaN               0
# 18                                                 NaN               0
# 19                                                 NaN               0
# 20                                                 NaN               0
# 21                                                 NaN               0
# 22                                                 NaN               0
# 23                                                 NaN               0
# 24                                                 NaN               0
# 25                                                 NaN               0
# 26                                                 NaN               0
# 27                                                 NaN               0
# 28                                                 NaN               0
# 29                                                 NaN               0
# ..                                                 ...             ...
# 148                                                NaN               0
# 149  {'media': [{'id': 746716677233065985, 'id_str'...               0
# 150                                                NaN               0
# 151                                                NaN               0
# 152                                                NaN               0
# 153                                                NaN               0
# 154                                                NaN               0
# 155                                                NaN               0
# 156                                                NaN               0
# 157                                                NaN               0
# 158                                                NaN               0
# 159                                                NaN               0
# 160                                                NaN               0
# 161                                                NaN               0
# 162                                                NaN               0
# 163                                                NaN               0
# 164                                                NaN               0
# 165                                                NaN               0
# 166                                                NaN               0
# 167                                                NaN               0
# 168                                                NaN               0
# 169                                                NaN               0
# 170                                                NaN               0
# 171                                                NaN               0
# 172                                                NaN               0
# 173                                                NaN               0
# 174                                                NaN               0
# 175  {'media': [{'id': 748514715618394112, 'id_str'...               0
# 176                                                NaN               0
# 177  {'media': [{'id': 748613978549542912, 'id_str'...               0
#
#      favorited filter_level   geo                  id  \
# 0        False          low  None  737221966730539008
# 1        False          low  None  737224281856167936
# 2        False          low  None  737228239169544192
# 3        False          low  None  737229374131408896
# 4        False          low  None  737235740531138560
# 5        False          low  None  737244865671626752
# 6        False          low  None  737255344150319104
# 7        False          low  None  737260189670211584
# 8        False          low  None  737555849573371910
# 9        False          low  None  737584219547832324
# 10       False          low  None  737956705711988736
# 11       False          low  None  737979183599652864
# 12       False          low  None  737994003602378752
# 13       False          low  None  738027663185608704
# 14       False          low  None  738030176567742465
# 15       False          low  None  738032875858210816
# 16       False          low  None  738043422532075520
# 17       False          low  None  738063756266201088
# 18       False          low  None  738077574191022080
# 19       False          low  None  738116102077730817
# 20       False          low  None  738286568352452608
# 21       False          low  None  738320170603667456
# 22       False          low  None  738321568401620992
# 23       False          low  None  738323426478333952
# 24       False          low  None  738330617486675968
# 25       False          low  None  738332475278143488
# 26       False          low  None  738332936152469505
# 27       False          low  None  738343607728476160
# 28       False          low  None  738410721780858880
# 29       False          low  None  738417579937681410
# ..         ...          ...   ...                 ...
# 148      False          low  None  746638290015617024
# 149      False          low  None  746716701568438272
# 150      False          low  None  746741219712188416
# 151      False          low  None  747391263066963968
# 152      False          low  None  747415842791489536
# 153      False          low  None  747430163550461952
# 154      False          low  None  747458924740218881
# 155      False          low  None  747480693932843012
# 156      False          low  None  747669949347409920
# 157      False          low  None  747694193380823040
# 158      False          low  None  747810742519365632
# 159      False          low  None  747813575465406464
# 160      False          low  None  747873804517511169
# 161      False          low  None  747893238007201792
# 162      False          low  None  747930171366322178
# 163      False          low  None  748036141992022016
# 164      False          low  None  748043707925037056
# 165      False          low  None  748058025995476992
# 166      False          low  None  748103262570582017
# 167      False          low  None  748105234501742592
# 168      False          low  None  748118327940218880
# 169      False          low  None  748129516053209088
# 170      False          low  None  748151928996106242
# 171      False          low  None  748157717882245120
# 172      False          low  None  748391454045777920
# 173      False          low  None  748444150173962240
# 174      False          low  None  748506039834710016
# 175      False          low  None  748514718113992704
# 176      False          low  None  748574020170301448
# 177      False          low  None  748613981389131776
#
#                            ...                         lang  \
# 0                          ...                           en
# 1                          ...                           en
# 2                          ...                           en
# 3                          ...                           nl
# 4                          ...                           en
# 5                          ...                           en
# 6                          ...                           en
# 7                          ...                           en
# 8                          ...                           nl
# 9                          ...                           nl
# 10                         ...                           en
# 11                         ...                           de
# 12                         ...                           de
# 13                         ...                           nl
# 14                         ...                           nl
# 15                         ...                           en
# 16                         ...                           nl
# 17                         ...                           en
# 18                         ...                           en
# 19                         ...                           nl
# 20                         ...                           nl
# 21                         ...                           en
# 22                         ...                           en
# 23                         ...                           nl
# 24                         ...                           nl
# 25                         ...                           nl
# 26                         ...                          und
# 27                         ...                           en
# 28                         ...                           en
# 29                         ...                           ko
# ..                         ...                          ...
# 148                        ...                           en
# 149                        ...                           en
# 150                        ...                           nl
# 151                        ...                           en
# 152                        ...                           en
# 153                        ...                           nl
# 154                        ...                           nl
# 155                        ...                           en
# 156                        ...                           nl
# 157                        ...                           nl
# 158                        ...                           nl
# 159                        ...                           en
# 160                        ...                           it
# 161                        ...                           en
# 162                        ...                           en
# 163                        ...                           en
# 164                        ...                           ko
# 165                        ...                           en
# 166                        ...                           ko
# 167                        ...                           nl
# 168                        ...                           nl
# 169                        ...                           nl
# 170                        ...                           nl
# 171                        ...                           en
# 172                        ...                           nl
# 173                        ...                           en
# 174                        ...                           ko
# 175                        ...                           en
# 176                        ...                           en
# 177                        ...                           nl
#
#                                                  place  possibly_sensitive  \
# 0                                                 None                 NaN
# 1                                                 None                 NaN
# 2                                                 None                 NaN
# 3                                                 None                 NaN
# 4                                                 None                 NaN
# 5                                                 None                 NaN
# 6                                                 None                 NaN
# 7                                                 None                 NaN
# 8    {'id': '6841ca0e149652bc', 'url': 'https://api...                 NaN
# 9                                                 None                 NaN
# 10                                                None                 NaN
# 11                                                None                 NaN
# 12                                                None                 NaN
# 13                                                None                 NaN
# 14                                                None                 NaN
# 15                                                None                 NaN
# 16                                                None                 NaN
# 17                                                None                 NaN
# 18                                                None                 NaN
# 19                                                None                 NaN
# 20                                                None                 NaN
# 21                                                None                 NaN
# 22                                                None                 NaN
# 23                                                None                 NaN
# 24                                                None                 NaN
# 25                                                None                 NaN
# 26                                                None                 NaN
# 27                                                None                 NaN
# 28                                                None                 NaN
# 29                                                None                 NaN
# ..                                                 ...                 ...
# 148                                               None                 NaN
# 149                                               None               False
# 150  {'id': '23f8a07383ac617e', 'url': 'https://api...                 NaN
# 151                                               None                 NaN
# 152                                               None                 NaN
# 153                                               None                 NaN
# 154                                               None                 NaN
# 155                                               None                 NaN
# 156                                               None                 NaN
# 157                                               None                 NaN
# 158                                               None                 NaN
# 159                                               None                 NaN
# 160                                               None                 NaN
# 161                                               None                 NaN
# 162                                               None                 NaN
# 163                                               None                 NaN
# 164                                               None               False
# 165                                               None                 NaN
# 166                                               None               False
# 167                                               None                 NaN
# 168                                               None                 NaN
# 169                                               None                 NaN
# 170                                               None                 NaN
# 171                                               None                 NaN
# 172                                               None                 NaN
# 173                                               None                 NaN
# 174                                               None               False
# 175                                               None               False
# 176                                               None                 NaN
# 177                                               None               False
#
#     retweet_count  retweeted  \
# 0               0      False
# 1               0      False
# 2               0      False
# 3               0      False
# 4               0      False
# 5               0      False
# 6               0      False
# 7               0      False
# 8               0      False
# 9               0      False
# 10              0      False
# 11              0      False
# 12              0      False
# 13              0      False
# 14              0      False
# 15              0      False
# 16              0      False
# 17              0      False
# 18              0      False
# 19              0      False
# 20              0      False
# 21              0      False
# 22              0      False
# 23              0      False
# 24              0      False
# 25              0      False
# 26              0      False
# 27              0      False
# 28              0      False
# 29              0      False
# ..            ...        ...
# 148             0      False
# 149             0      False
# 150             0      False
# 151             0      False
# 152             0      False
# 153             0      False
# 154             0      False
# 155             0      False
# 156             0      False
# 157             0      False
# 158             0      False
# 159             0      False
# 160             0      False
# 161             0      False
# 162             0      False
# 163             0      False
# 164             0      False
# 165             0      False
# 166             0      False
# 167             0      False
# 168             0      False
# 169             0      False
# 170             0      False
# 171             0      False
# 172             0      False
# 173             0      False
# 174             0      False
# 175             0      False
# 176             0      False
# 177             0      False
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://twitter.com/download/android" ...
# 2    <a href="http://twitter.com/download/android" ...
# 3    <a href="http://twitter.com/download/iphone" r...
# 4    <a href="http://twitter.com" rel="nofollow">Tw...
# 5    <a href="http://twitter.com/download/android" ...
# 6    <a href="http://twitter.com/download/android" ...
# 7    <a href="http://twitter.com/download/iphone" r...
# 8    <a href="http://twitter.com" rel="nofollow">Tw...
# 9    <a href="http://twitter.com" rel="nofollow">Tw...
# 10   <a href="http://twitter.com/#!/download/ipad" ...
# 11   <a href="http://twitter.com" rel="nofollow">Tw...
# 12   <a href="http://twitter.com" rel="nofollow">Tw...
# 13   <a href="http://twitter.com" rel="nofollow">Tw...
# 14   <a href="http://twitter.com/download/android" ...
# 15   <a href="http://twitter.com/#!/download/ipad" ...
# 16   <a href="http://twitter.com" rel="nofollow">Tw...
# 17   <a href="http://www.twitter.com" rel="nofollow...
# 18   <a href="http://twitter.com/download/android" ...
# 19   <a href="http://twitter.com/download/iphone" r...
# 20   <a href="http://twitter.com" rel="nofollow">Tw...
# 21   <a href="http://twitter.com/download/iphone" r...
# 22   <a href="http://twitter.com" rel="nofollow">Tw...
# 23   <a href="http://twitter.com" rel="nofollow">Tw...
# 24   <a href="http://twitter.com" rel="nofollow">Tw...
# 25   <a href="http://twitter.com/download/iphone" r...
# 26   <a href="http://twitter.com/download/android" ...
# 27   <a href="http://twitter.com/download/android" ...
# 28   <a href="http://tapbots.com/tweetbot" rel="nof...
# 29   <a href="http://itunes.apple.com/us/app/twitte...
# ..                                                 ...
# 148  <a href="http://twitter.com/download/android" ...
# 149  <a href="http://twitter.com/download/iphone" r...
# 150  <a href="http://twitter.com/download/android" ...
# 151  <a href="http://twitter.com/download/iphone" r...
# 152  <a href="http://twitter.com/download/android" ...
# 153  <a href="http://twitter.com/download/iphone" r...
# 154  <a href="http://twitter.com/download/iphone" r...
# 155  <a href="http://twitter.com/download/iphone" r...
# 156  <a href="https://mobile.twitter.com" rel="nofo...
# 157  <a href="http://www.twitter.com" rel="nofollow...
# 158  <a href="http://twitter.com/download/iphone" r...
# 159  <a href="http://twitter.com/download/iphone" r...
# 160  <a href="http://twitter.com/download/iphone" r...
# 161  <a href="http://twitter.com/download/android" ...
# 162  <a href="http://twitter.com/download/iphone" r...
# 163  <a href="https://mobile.twitter.com" rel="nofo...
# 164  <a href="http://twitter.com" rel="nofollow">Tw...
# 165  <a href="https://mobile.twitter.com" rel="nofo...
# 166  <a href="http://twitter.com" rel="nofollow">Tw...
# 167  <a href="http://twitter.com/download/iphone" r...
# 168  <a href="http://twitter.com" rel="nofollow">Tw...
# 169  <a href="http://twitter.com/download/iphone" r...
# 170  <a href="http://twitter.com/download/iphone" r...
# 171  <a href="http://twitter.com" rel="nofollow">Tw...
# 172  <a href="http://twitter.com/download/android" ...
# 173  <a href="http://twitter.com" rel="nofollow">Tw...
# 174  <a href="http://twitter.com" rel="nofollow">Tw...
# 175  <a href="http://tapbots.com/tweetbot" rel="nof...
# 176  <a href="http://twitter.com/download/iphone" r...
# 177  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text   timestamp_ms  \
# 0    I have to say @KLM staff have been superb with...  1464602388447
# 1          @KLM what is replacing her? New 747 or A380  1464602940416
# 2             @KLM When are your 747s being withdrawn?  1464603883913
# 3    @KLM 2 vragen. Hoeveel kg mag je in het koffer...  1464604154509
# 4    . @KLM @solitarybrother WoW soon? But the refe...  1464605672377
# 5    How i wish i to be on @KLM one day to United K...  1464607847980
# 6    @klm i couldn't find flight to Gatwick, do you...  1464610346244
# 7       @KLM the new A-380 is coming to the KLM town??  1464611501506
# 8    @KLM ik probeer jullie te bellen, heb namelijk...  1464681992320
# 9    @KLM ben op zoek naar een nieuwe uitdaging, zo...  1464688756249
# 10   @KLM because you are getting a fleet of A380's...  1464777563871
# 11   @KLM_DE Warum teilt KLM eigentlich ein Foto, d...  1464782923017
# 12   @KLM Haha, was für ne Ausrede... :D Ich gehe d...  1464786456381
# 13   @KLM Hi! Op bepaalde vluchten zijn er geen bag...  1464794481451
# 14                     @KLM per vlucht of per boeking?  1464795080688
# 15   @KLM I would be grateful if you could explain ...  1464795724249
# 16   @KLM als ik via Kenya airways tickets voor KLM...  1464798238772
# 17   @KLM how many liter of wine os allowed to brin...  1464803086712
# 18   Really hoping @KLM @KLM_UK have WiFi on their ...  1464806381162
# 19   @klm met ivory flying blue kaart mag je dan gr...  1464815566926
# 20   @KLM Hallo KLM, kunnen jullie meer info geven ...  1464856209253
# 21   @KLM my flight was delayed by over 3 hours - a...  1464864220654
# 22   @KLM Violating my privacy by finding me on fac...  1464864553915
# 23   @KLM Precies 'Mijn Reis" foutje ;) maar kan ik...  1464864996915
# 24   @KLM Wat gek als ik een retour wil boeken is t...  1464866711385
# 25   @KLM bij jullie is meer dan 2 keer duurder. Wa...  1464867154317
# 26                                              @KLM 😆  1464867264198
# 27   @KLM The reason why is still not completely cl...  1464869808500
# 28   @KLM how many kg baggage allowed in KLM flight...  1464885809737
# 29   예전에 노르웨이 같이 교환학생 했던 언니랑 같이 수다 떠는데 언니 말이 언니는 언제...  1464887444849
# ..                                                 ...            ...
# 148  @KLM how do I go about buying two bike boxes? ...  1466847414865
# 149  I know I am in safe hands to Beijing with @GEA...  1466866109636
# 150  Oh @KLM, ik houd van je maar 70 EUR voor 2kg t...  1466871955217
# 151  @KLM yeah of course really like it! It stood o...  1467026937630
# 152  @KLM where to pick up my unaccompanied nephew ...  1467032797893
# 153  @KLM ik ren me rot! Enige kans om de gate te w...  1467036212228
# 154  @KLM hoe laat moeten we uiterlijk inchecken op...  1467043069430
# 155  @KLM \n\nHope so ❤️\nWish my dream come true ❤...  1467048259610
# 156  @KLM dank voor snelle reactie.  Graag ook een ...  1467093381617
# 157  @KLM  school vn zn  hft gn geld voor schoolrei...  1467099161845
# 158              @KLM Sorry, had wel al bericht! Dank!  1467126949325
# 159  Ok maybe emirates stewardess r colourful &amp;...  1467127624752
# 160  @KLM vorrei sapere il peso massimo per bagagli...  1467141984477
# 161  @KLM @KLM_UK @KLM_US  Are the flights canceled...  1467146617782
# 162  @Delta Hi there! Tomorrow we're flying from JF...  1467155423381
# 163  @KLM can i bring buggy and car seat free of ch...  1467180688747
# 164  KLM VR travel experience in Korea: KLM 암스테르담 전...  1467182492606
# 165   @klm thanks, Read it but what about my car seat?  1467185906300
# 166  KLM VR travel experience in Korea: KLM 암스테르담 전...  1467196691540
# 167  @KLM @TUINederland @Dreizen @Sunweb Help mij e...  1467197161685
# 168  @KLM Heffen jullie de air passenger tax voor v...  1467200283404
# 169  @KLM Helder. PIR gemeld. Nu zaak om te weten o...  1467202950858
# 170  @KLM ik kan aan een medische verklaring komen ...  1467208294520
# 171          @airfarewatchdog @KLM  cool -- I love KLM  1467209674698
# 172  @klm moet ik nu al voor stoelen betalen van te...  1467265401742
# 173                         @KLM From WAW to Amsterdam  1467277965478
# 174  KLM VR travel experience in Korea: KLM 암스테르담 전...  1467292721123
# 175  @KLM Your app seems not to be working properly...  1467294790186
# 176  @KLM what is the latest I can arrive at schipp...  1467308928898
# 177  @klm Erg pijnlijk dat na fout gaan van de beta...  1467318456395
#
#     truncated                                               user
# 0       False  {'id': 95059891, 'id_str': '95059891', 'name':...
# 1       False  {'id': 3371210360, 'id_str': '3371210360', 'na...
# 2       False  {'id': 3179444548, 'id_str': '3179444548', 'na...
# 3       False  {'id': 25361927, 'id_str': '25361927', 'name':...
# 4       False  {'id': 329090201, 'id_str': '329090201', 'name...
# 5       False  {'id': 263316942, 'id_str': '263316942', 'name...
# 6       False  {'id': 273536637, 'id_str': '273536637', 'name...
# 7       False  {'id': 3161622738, 'id_str': '3161622738', 'na...
# 8       False  {'id': 91069982, 'id_str': '91069982', 'name':...
# 9       False  {'id': 70474418, 'id_str': '70474418', 'name':...
# 10      False  {'id': 142023225, 'id_str': '142023225', 'name...
# 11      False  {'id': 3240396143, 'id_str': '3240396143', 'na...
# 12      False  {'id': 3240396143, 'id_str': '3240396143', 'na...
# 13      False  {'id': 186145173, 'id_str': '186145173', 'name...
# 14      False  {'id': 153095772, 'id_str': '153095772', 'name...
# 15      False  {'id': 3035452282, 'id_str': '3035452282', 'na...
# 16      False  {'id': 2729286090, 'id_str': '2729286090', 'na...
# 17      False  {'id': 701787234, 'id_str': '701787234', 'name...
# 18      False  {'id': 2796504429, 'id_str': '2796504429', 'na...
# 19      False  {'id': 18550763, 'id_str': '18550763', 'name':...
# 20      False  {'id': 2824499652, 'id_str': '2824499652', 'na...
# 21      False  {'id': 21890710, 'id_str': '21890710', 'name':...
# 22      False  {'id': 1151639504, 'id_str': '1151639504', 'na...
# 23      False  {'id': 49595911, 'id_str': '49595911', 'name':...
# 24      False  {'id': 737241259480391680, 'id_str': '73724125...
# 25      False  {'id': 1397845136, 'id_str': '1397845136', 'na...
# 26      False  {'id': 274629041, 'id_str': '274629041', 'name...
# 27      False  {'id': 154997522, 'id_str': '154997522', 'name...
# 28      False  {'id': 277404065, 'id_str': '277404065', 'name...
# 29      False  {'id': 2718667471, 'id_str': '2718667471', 'na...
# ..        ...                                                ...
# 148     False  {'id': 257567296, 'id_str': '257567296', 'name...
# 149     False  {'id': 142008764, 'id_str': '142008764', 'name...
# 150     False  {'id': 15383031, 'id_str': '15383031', 'name':...
# 151     False  {'id': 1862534881, 'id_str': '1862534881', 'na...
# 152     False  {'id': 713489638330122240, 'id_str': '71348963...
# 153     False  {'id': 25140479, 'id_str': '25140479', 'name':...
# 154     False  {'id': 122380702, 'id_str': '122380702', 'name...
# 155     False  {'id': 2882073145, 'id_str': '2882073145', 'na...
# 156     False  {'id': 145210064, 'id_str': '145210064', 'name...
# 157     False  {'id': 3141811757, 'id_str': '3141811757', 'na...
# 158     False  {'id': 76639038, 'id_str': '76639038', 'name':...
# 159     False  {'id': 287012796, 'id_str': '287012796', 'name...
# 160     False  {'id': 445640353, 'id_str': '445640353', 'name...
# 161     False  {'id': 189849811, 'id_str': '189849811', 'name...
# 162     False  {'id': 299793643, 'id_str': '299793643', 'name...
# 163     False  {'id': 5395082, 'id_str': '5395082', 'name': '...
# 164     False  {'id': 138434853, 'id_str': '138434853', 'name...
# 165     False  {'id': 5395082, 'id_str': '5395082', 'name': '...
# 166     False  {'id': 138434853, 'id_str': '138434853', 'name...
# 167     False  {'id': 1100450478, 'id_str': '1100450478', 'na...
# 168     False  {'id': 76660943, 'id_str': '76660943', 'name':...
# 169     False  {'id': 312564251, 'id_str': '312564251', 'name...
# 170     False  {'id': 184706222, 'id_str': '184706222', 'name...
# 171     False  {'id': 37444367, 'id_str': '37444367', 'name':...
# 172     False  {'id': 257591113, 'id_str': '257591113', 'name...
# 173     False  {'id': 3823982963, 'id_str': '3823982963', 'na...
# 174     False  {'id': 154761604, 'id_str': '154761604', 'name...
# 175     False  {'id': 1279741, 'id_str': '1279741', 'name': '...
# 176     False  {'id': 217352791, 'id_str': '217352791', 'name...
# 177     False  {'id': 67894244, 'id_str': '67894244', 'name':...
#
# [178 rows x 27 columns]

# %%
data = pandas.DataFrame(data)
